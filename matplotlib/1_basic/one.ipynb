# %%
import pandas as pd
import matplotlib.pyplot as plt

air_quality = pd.read_csv("../data/air_quality_no2.csv", index_col=0, parse_dates=True)
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
air_quality['station_paris'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
# I want to visually compare the values measured in London versus Paris.

air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.3)
plt.show()

# %%
# Name of the methods that are exists

[
    method_name
    for method_name in dir(air_quality.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_quality.plot.area(x="station_london", y="station_paris", stacked=True,alpha=0.3)
# Out:
# <Axes: xlabel='station_london'>

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)
axs
# Out:
# array([<Axes: xlabel='datetime'>, <Axes: xlabel='datetime'>,
#        <Axes: xlabel='datetime'>], dtype=object)

# %%
axs = air_quality.plot.area(figsize=(12, 4))
axs
# Out:
# <Axes: xlabel='datetime'>

# %%
fig, axs = plt.subplots(figsize=(12, 4))
air_quality.plot.area(ax=axs)

axs.set_ylabel("NO$_2$ concentration")
# fig.savefig("no2_concentrations.png")
plt.show()
